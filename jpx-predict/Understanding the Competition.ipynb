# %% [markdown]
# # Import Necessary Libraries

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Exploration

# %%
sample_df = pd.read_csv("D:/kaggle/jpx-prediction/example_test_files/sample_submission.csv")
sample_df
# Out:
#               Date  SecuritiesCode  Rank
# 0       2021-12-06            1301     0
# 1       2021-12-06            1332     1
# 2       2021-12-06            1333     2
# 3       2021-12-06            1375     3
# 4       2021-12-06            1376     4
# ...            ...             ...   ...
# 111995  2022-02-28            9990  1995
# 111996  2022-02-28            9991  1996
# 111997  2022-02-28            9993  1997
# 111998  2022-02-28            9994  1998
# 111999  2022-02-28            9997  1999
#
# [112000 rows x 3 columns]

# %% [markdown]
# # Calculating the target of the dataset
# > Goal: Try to calculate the change rate of close of the next two days

# %%
stock_df = pd.read_csv('D:/kaggle/jpx-prediction/train_files/stock_prices.csv')
stock_df
# Out:
#                  RowId        Date  SecuritiesCode    Open    High     Low  \
# 0        20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0
# 1        20170104_1332  2017-01-04            1332   568.0   576.0   563.0
# 2        20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0
# 3        20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0
# 4        20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0
# ...                ...         ...             ...     ...     ...     ...
# 2332526  20211203_9990  2021-12-03            9990   514.0   528.0   513.0
# 2332527  20211203_9991  2021-12-03            9991   782.0   794.0   782.0
# 2332528  20211203_9993  2021-12-03            9993  1690.0  1690.0  1645.0
# 2332529  20211203_9994  2021-12-03            9994  2388.0  2396.0  2380.0
# 2332530  20211203_9997  2021-12-03            9997   690.0   711.0   686.0
#
# ...

# %%
stock_df["Date"] = pd.to_datetime(stock_df["Date"])

# %%
temp_df = stock_df[stock_df["SecuritiesCode"]==1301].reset_index(drop=True)
temp_df
# Out:
#               RowId       Date  SecuritiesCode    Open    High     Low  \
# 0     20170104_1301 2017-01-04            1301  2734.0  2755.0  2730.0
# 1     20170105_1301 2017-01-05            1301  2743.0  2747.0  2735.0
# 2     20170106_1301 2017-01-06            1301  2734.0  2744.0  2720.0
# 3     20170110_1301 2017-01-10            1301  2745.0  2754.0  2735.0
# 4     20170111_1301 2017-01-11            1301  2748.0  2752.0  2737.0
# ...             ...        ...             ...     ...     ...     ...
# 1197  20211129_1301 2021-11-29            1301  2975.0  2984.0  2951.0
# 1198  20211130_1301 2021-11-30            1301  2953.0  2997.0  2900.0
# 1199  20211201_1301 2021-12-01            1301  2909.0  2936.0  2909.0
# 1200  20211202_1301 2021-12-02            1301  2949.0  2973.0  2933.0
# 1201  20211203_1301 2021-12-03            1301  2983.0  2983.0  2965.0
#
#        Close  Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %%
(temp_df["Close"].shift(-2) - temp_df["Close"].shift(-1))/temp_df["Close"].shift(-1)
# Out:
# 0       0.000730
# 1       0.002920
# 2      -0.001092
# 3      -0.005100
# 4      -0.003295
#           ...
# 1197    0.003793
# 1198    0.007558
# 1199    0.016706
# 1200         NaN
# 1201         NaN
# Name: Close, Length: 1202, dtype: float64

# %% [markdown]
# # Ranking the Stocks

# %%
temp_df2 = stock_df[stock_df["Date"]=='2021-12-02'].reset_index(drop=True)
temp_df2
# Out:
#               RowId       Date  SecuritiesCode    Open    High     Low  \
# 0     20211202_1301 2021-12-02            1301  2949.0  2973.0  2933.0
# 1     20211202_1332 2021-12-02            1332   566.0   577.0   565.0
# 2     20211202_1333 2021-12-02            1333  2276.0  2314.0  2267.0
# 3     20211202_1375 2021-12-02            1375  1220.0  1244.0  1209.0
# 4     20211202_1376 2021-12-02            1376  1353.0  1373.0  1327.0
# ...             ...        ...             ...     ...     ...     ...
# 1995  20211202_9990 2021-12-02            9990   518.0   519.0   507.0
# 1996  20211202_9991 2021-12-02            9991   777.0   791.0   775.0
# 1997  20211202_9993 2021-12-02            9993  1672.0  1685.0  1650.0
# 1998  20211202_9994 2021-12-02            9994  2340.0  2382.0  2340.0
# 1999  20211202_9997 2021-12-02            9997   681.0   692.0   680.0
#
#        Close   Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %%
temp_df2["rank"] = temp_df2["Target"].rank(ascending=False, method="first") - 1
temp_df2 = temp_df2.sort_values("rank").reset_index(drop=True)
temp_df2
# Out:
#               RowId       Date  SecuritiesCode    Open    High     Low  \
# 0     20211202_4699 2021-12-02            4699  2037.0  2149.0  2037.0
# 1     20211202_4488 2021-12-02            4488  5900.0  5990.0  5690.0
# 2     20211202_8057 2021-12-02            8057  4710.0  4820.0  4615.0
# 3     20211202_9632 2021-12-02            9632  8110.0  8150.0  8000.0
# 4     20211202_6958 2021-12-02            6958   510.0   525.0   502.0
# ...             ...        ...             ...     ...     ...     ...
# 1995  20211202_4483 2021-12-02            4483  8200.0  8590.0  8180.0
# 1996  20211202_6879 2021-12-02            6879   731.0   745.0   702.0
# 1997  20211202_4168 2021-12-02            4168  4280.0  4390.0  4200.0
# 1998  20211202_3994 2021-12-02            3994  7490.0  7500.0  7060.0
# 1999  20211202_4169 2021-12-02            4169  7160.0  7870.0  7110.0
#
#        Close  Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %% [markdown]
# # Calculate daily spread return of one day

# %%
top200 = temp_df2.iloc[:200, :]
top200
# Out:
#              RowId       Date  SecuritiesCode    Open    High     Low   Close  \
# 0    20211202_4699 2021-12-02            4699  2037.0  2149.0  2037.0  2143.0
# 1    20211202_4488 2021-12-02            4488  5900.0  5990.0  5690.0  5700.0
# 2    20211202_8057 2021-12-02            8057  4710.0  4820.0  4615.0  4640.0
# 3    20211202_9632 2021-12-02            9632  8110.0  8150.0  8000.0  8030.0
# 4    20211202_6958 2021-12-02            6958   510.0   525.0   502.0   517.0
# ..             ...        ...             ...     ...     ...     ...     ...
# 195  20211202_6272 2021-12-02            6272  1291.0  1343.0  1291.0  1308.0
# 196  20211202_6324 2021-12-02            6324  4500.0  4635.0  4400.0  4490.0
# 197  20211202_2899 2021-12-02            2899  1899.0  1919.0  1880.0  1906.0
# 198  20211202_2185 2021-12-02            2185  1376.0  1376.0  1355.0  1355.0
# 199  20211202_4203 2021-12-02            4203  5390.0  5500.0  5310.0  5350.0
#
# ...

# %%
weights = np.linspace(start=2, stop=1, num=200)
weights
# Out:
# array([2.        , 1.99497487, 1.98994975, 1.98492462, 1.9798995 ,
#        1.97487437, 1.96984925, 1.96482412, 1.95979899, 1.95477387,
#        1.94974874, 1.94472362, 1.93969849, 1.93467337, 1.92964824,
#        1.92462312, 1.91959799, 1.91457286, 1.90954774, 1.90452261,
#        1.89949749, 1.89447236, 1.88944724, 1.88442211, 1.87939698,
#        1.87437186, 1.86934673, 1.86432161, 1.85929648, 1.85427136,
#        1.84924623, 1.84422111, 1.83919598, 1.83417085, 1.82914573,
#        1.8241206 , 1.81909548, 1.81407035, 1.80904523, 1.8040201 ,
#        1.79899497, 1.79396985, 1.78894472, 1.7839196 , 1.77889447,
#        1.77386935, 1.76884422, 1.7638191 , 1.75879397, 1.75376884,
#        1.74874372, 1.74371859, 1.73869347, 1.73366834, 1.72864322,
#        1.72361809, 1.71859296, 1.71356784, 1.70854271, 1.70351759,
#        1.69849246, 1.69346734, 1.68844221, 1.68341709, 1.67839196,
#        1.67336683, 1.66834171, 1.66331658, 1.65829146, 1.65326633,
# ...

# %%
top200["weights"] = weights
top200.head()
# Out:
# C:\Users\Kaleb\AppData\Local\Temp/ipykernel_4396/584338425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top200["weights"] = weights
#            RowId       Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4699 2021-12-02            4699  2037.0  2149.0  2037.0  2143.0
# 1  20211202_4488 2021-12-02            4488  5900.0  5990.0  5690.0  5700.0
# 2  20211202_8057 2021-12-02            8057  4710.0  4820.0  4615.0  4640.0
# 3  20211202_9632 2021-12-02            9632  8110.0  8150.0  8000.0  8030.0
# 4  20211202_6958 2021-12-02            6958   510.0   525.0   502.0   517.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# ...

# %%
top200["calc_weights"] = top200["Target"] * top200["weights"]
top200.head()
# Out:
# C:\Users\Kaleb\AppData\Local\Temp/ipykernel_4396/2897131899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top200["calc_weights"] = top200["Target"] * top200["weights"]
#            RowId       Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4699 2021-12-02            4699  2037.0  2149.0  2037.0  2143.0
# 1  20211202_4488 2021-12-02            4488  5900.0  5990.0  5690.0  5700.0
# 2  20211202_8057 2021-12-02            8057  4710.0  4820.0  4615.0  4640.0
# 3  20211202_9632 2021-12-02            9632  8110.0  8150.0  8000.0  8030.0
# 4  20211202_6958 2021-12-02            6958   510.0   525.0   502.0   517.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# ...

# %%
S_up = top200["calc_weights"].sum()/np.mean(weights)
S_up
# Out:
# 5.806640386677844

# %%
bot200 = temp_df2.iloc[-200:, :]
bot200 = bot200.sort_values("rank", ascending=False).reset_index(drop=True)
bot200
# Out:
#              RowId       Date  SecuritiesCode     Open     High      Low  \
# 0    20211202_4169 2021-12-02            4169   7160.0   7870.0   7110.0
# 1    20211202_3994 2021-12-02            3994   7490.0   7500.0   7060.0
# 2    20211202_4168 2021-12-02            4168   4280.0   4390.0   4200.0
# 3    20211202_6879 2021-12-02            6879    731.0    745.0    702.0
# 4    20211202_4483 2021-12-02            4483   8200.0   8590.0   8180.0
# ..             ...        ...             ...      ...      ...      ...
# 195  20211202_4482 2021-12-02            4482    940.0    972.0    915.0
# 196  20211202_7990 2021-12-02            7990   3375.0   3390.0   3290.0
# 197  20211202_6920 2021-12-02            6920  29950.0  30360.0  29540.0
# 198  20211202_4620 2021-12-02            4620    502.0    511.0    501.0
# 199  20211202_8285 2021-12-02            8285    299.0    303.0    299.0
#
#        Close   Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %%
bot200["weights"] = weights
bot200.head()
# Out:
#            RowId       Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4169 2021-12-02            4169  7160.0  7870.0  7110.0  7520.0
# 1  20211202_3994 2021-12-02            3994  7490.0  7500.0  7060.0  7070.0
# 2  20211202_4168 2021-12-02            4168  4280.0  4390.0  4200.0  4335.0
# 3  20211202_6879 2021-12-02            6879   731.0   745.0   702.0   707.0
# 4  20211202_4483 2021-12-02            4483  8200.0  8590.0  8180.0  8410.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# 0  783000               1.0               NaN            False -0.127424
# 1  735000               1.0               NaN            False -0.094980
# 2   72600               1.0               NaN            False -0.094595
# 3  735500               1.0               NaN            False -0.087248
# 4  320300               1.0               NaN            False -0.085480
#
#      rank   weights
# 0  1999.0  2.000000
# 1  1998.0  1.994975
# ...

# %%
bot200["calc_weights"] = bot200["Target"] * bot200["weights"]
bot200.head()
# Out:
#            RowId       Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4169 2021-12-02            4169  7160.0  7870.0  7110.0  7520.0
# 1  20211202_3994 2021-12-02            3994  7490.0  7500.0  7060.0  7070.0
# 2  20211202_4168 2021-12-02            4168  4280.0  4390.0  4200.0  4335.0
# 3  20211202_6879 2021-12-02            6879   731.0   745.0   702.0   707.0
# 4  20211202_4483 2021-12-02            4483  8200.0  8590.0  8180.0  8410.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# 0  783000               1.0               NaN            False -0.127424
# 1  735000               1.0               NaN            False -0.094980
# 2   72600               1.0               NaN            False -0.094595
# 3  735500               1.0               NaN            False -0.087248
# 4  320300               1.0               NaN            False -0.085480
#
#      rank   weights  calc_weights
# 0  1999.0  2.000000     -0.254848
# ...

# %%
S_down = bot200["calc_weights"].sum()/np.mean(weights)
S_down
# Out:
# -9.10891259103055

# %%
daily_spread_return = S_up - S_down
daily_spread_return
# Out:
# 14.915552977708394

# %%
def calc_spread_return_sharpe(df: pd.DataFrame, portfolio_size: int = 200, toprank_weight_ratio: float = 2) -> float:
    """
    Args:
        df (pd.DataFrame): predicted results
        portfolio_size (int): # of equities to buy/sell
        toprank_weight_ratio (float): the relative weight of the most highly ranked stock compared to the least.
    Returns:
        (float): sharpe ratio
    """
    def _calc_spread_return_per_day(df, portfolio_size, toprank_weight_ratio):
        """
        Args:
            df (pd.DataFrame): predicted results
            portfolio_size (int): # of equities to buy/sell
            toprank_weight_ratio (float): the relative weight of the most highly ranked stock compared to the least.
        Returns:
            (float): spread return
        """
        assert df['Rank'].min() == 0
        assert df['Rank'].max() == len(df['Rank']) - 1
        weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
        purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
        short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
        return purchase - short

    buf = df.groupby('Date').apply(_calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio
